# %% [markdown]
# # **¡Adivina el número!**

# %% [markdown]
# ## **Modificaciones/cambios pendientes**
# - Introducir más estadísticas como la dificultad en la que se ha jugado y si ha ganado o perdido
# - Canción en el menú, o durante el juego...

# %%
import guessthenumber as guess

# %%
guess.jugar()
