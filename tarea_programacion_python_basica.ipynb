# %% [markdown]
# # **¡Adivina el número!**

# %%
import guessthenumber as guess

# %%
guess.jugar()
# Out:
# 🎯==============================🎯
#      ¡ADIVINA EL NÚMERO! 🎲
# 🎯==============================🎯
#
# 1️⃣  Modo Solitario
#    🤖 Ponte a prueba contra el ordenador. ¡Demuestra lo que vales!
#
# 2️⃣  Modo Multijugador
#    👥 Un jugador elige el número, el otro intenta adivinarlo.
#
# 3️⃣  Estadísticas
#    📊 Consulta tus logros y puntuaciones guardadas.
#
# 4️⃣  Salir
#    🚪 Cierra el juego.
#
#
# Cargando...
#
#
# 📊 ESTADÍSTICAS DE JUEGO 📊
# ----------------------------------------------------------------------
#         Modo    Nombre  Número a adivinar  Intentos        Fecha y hora
#    Solitario     Gorka                192        12 2025-11-08 19:48:39
#    Solitario Annabelle                617         5 2025-11-08 19:54:00
#    Solitario    Ulises                251         5 2025-11-08 19:56:03
#    Solitario      Anna                133         5 2025-11-08 20:00:54
# Multijugador     Laura                876         4 2025-11-08 20:02:33
#    Solitario Annabelle                326        12 2025-11-08 20:03:16
#    Solitario      Paco                234         8 2025-11-08 20:05:18
# ----------------------------------------------------------------------
#
# 🎯==============================🎯
#      ¡ADIVINA EL NÚMERO! 🎲
# 🎯==============================🎯
#
# 1️⃣  Modo Solitario
#    🤖 Ponte a prueba contra el ordenador. ¡Demuestra lo que vales!
#
# 2️⃣  Modo Multijugador
#    👥 Un jugador elige el número, el otro intenta adivinarlo.
#
# 3️⃣  Estadísticas
#    📊 Consulta tus logros y puntuaciones guardadas.
#
# 4️⃣  Salir
#    🚪 Cierra el juego.
#
#
# Cargando...
#
#
# 📊 ESTADÍSTICAS DE JUEGO 📊
# ----------------------------------------------------------------------
#         Modo    Nombre  Número a adivinar  Intentos        Fecha y hora
#    Solitario     Gorka                192        12 2025-11-08 19:48:39
#    Solitario Annabelle                617         5 2025-11-08 19:54:00
#    Solitario    Ulises                251         5 2025-11-08 19:56:03
#    Solitario      Anna                133         5 2025-11-08 20:00:54
# Multijugador     Laura                876         4 2025-11-08 20:02:33
#    Solitario Annabelle                326        12 2025-11-08 20:03:16
#    Solitario      Paco                234         8 2025-11-08 20:05:18
# ----------------------------------------------------------------------
#
# 🎯==============================🎯
#      ¡ADIVINA EL NÚMERO! 🎲
# 🎯==============================🎯
#
# 1️⃣  Modo Solitario
#    🤖 Ponte a prueba contra el ordenador. ¡Demuestra lo que vales!
#
# 2️⃣  Modo Multijugador
#    👥 Un jugador elige el número, el otro intenta adivinarlo.
#
# 3️⃣  Estadísticas
#    📊 Consulta tus logros y puntuaciones guardadas.
#
# 4️⃣  Salir
#    🚪 Cierra el juego.
#
#
# Cargando...
#
#
# 📊 ESTADÍSTICAS DE JUEGO 📊
# ----------------------------------------------------------------------
#         Modo    Nombre  Número a adivinar  Intentos        Fecha y hora
#    Solitario     Gorka                192        12 2025-11-08 19:48:39
#    Solitario Annabelle                617         5 2025-11-08 19:54:00
#    Solitario    Ulises                251         5 2025-11-08 19:56:03
#    Solitario      Anna                133         5 2025-11-08 20:00:54
# Multijugador     Laura                876         4 2025-11-08 20:02:33
#    Solitario Annabelle                326        12 2025-11-08 20:03:16
#    Solitario      Paco                234         8 2025-11-08 20:05:18
# ----------------------------------------------------------------------
#
# 🎯==============================🎯
#      ¡ADIVINA EL NÚMERO! 🎲
# 🎯==============================🎯
#
# 1️⃣  Modo Solitario
#    🤖 Ponte a prueba contra el ordenador. ¡Demuestra lo que vales!
#
# 2️⃣  Modo Multijugador
#    👥 Un jugador elige el número, el otro intenta adivinarlo.
#
# 3️⃣  Estadísticas
#    📊 Consulta tus logros y puntuaciones guardadas.
#
# 4️⃣  Salir
#    🚪 Cierra el juego.
#
#
# ==================================
# 💪 ELIGE TU NIVEL DE DIFICULTAD 💪
# ==================================
#
# 🐣 1️⃣  Fácil — 20 intentos
#    🌼 Ideal para calentar motores y disfrutar sin prisas.
#
# 🔥 2️⃣  Medio — 12 intentos
#    ⚡ Un desafío equilibrado: ¡demuestra tu instinto!
#
# 💀 3️⃣  Difícil — 5 intentos
#    💣 Solo para valientes. ¿Te atreves?
#
# ↩️ 4️⃣  Volver al menú principal
#    🔙 ¿Cambiaste de idea?, ¡no pasa nada!
#
#
# 🔻 ¡Demasiado alto, bájale un poco!
#
#
# 🏂 Baja un poco, que te pasaste.
#
#
# 🏂 Baja un poco, que te pasaste.
#
#
# 🔻 ¡Demasiado alto, bájale un poco!
#
#
# 🚀 Necesitas apuntar más alto.
#
#
# 😢 Se acabaron los intentos. El número era 138.
#
#
# 💪 ¡No te rindas María! La próxima vez seguro lo consigues.
#
#
# 🎯==============================🎯
#      ¡ADIVINA EL NÚMERO! 🎲
# 🎯==============================🎯
#
# 1️⃣  Modo Solitario
#    🤖 Ponte a prueba contra el ordenador. ¡Demuestra lo que vales!
#
# 2️⃣  Modo Multijugador
#    👥 Un jugador elige el número, el otro intenta adivinarlo.
#
# 3️⃣  Estadísticas
#    📊 Consulta tus logros y puntuaciones guardadas.
#
# 4️⃣  Salir
#    🚪 Cierra el juego.
#
#
# ==================================
# 💪 ELIGE TU NIVEL DE DIFICULTAD 💪
# ==================================
#
# 🐣 1️⃣  Fácil — 20 intentos
#    🌼 Ideal para calentar motores y disfrutar sin prisas.
#
# 🔥 2️⃣  Medio — 12 intentos
#    ⚡ Un desafío equilibrado: ¡demuestra tu instinto!
#
# 💀 3️⃣  Difícil — 5 intentos
#    💣 Solo para valientes. ¿Te atreves?
#
# ↩️ 4️⃣  Volver al menú principal
#    🔙 ¿Cambiaste de idea?, ¡no pasa nada!
#
#
# 🔺 ¡Más arriba, más arriba!
#
#
# 🏂 Baja un poco, que te pasaste.
#
#
# 😏 El número es más grande...
#
#
# 🧗‍♂️ Piensa en algo más grande.
#
#
# 😅 No tan alto, intenta más bajo.
#
#
# 🐜 El número es más pequeño que ese.
#
#
# 🔻 ¡Demasiado alto, bájale un poco!
#
#
# 🏂 Baja un poco, que te pasaste.
#
#
# 🔻 ¡Demasiado alto, bájale un poco!
#
#
# 😅 No tan alto, intenta más bajo.
#
#
# 🏂 Baja un poco, que te pasaste.
#
#
# 📈 Sube un poco más, ¡casi llegas!
#
#
# 😏 El número es más grande...
#
#
# 📈 Sube un poco más, ¡casi llegas!
#
#
# 😏 El número es más grande...
#
#
# 🧗‍♂️ Piensa en algo más grande.
#
#
# 😏 El número es más grande...
#
#
# 🔺 ¡Más arriba, más arriba!
#
#
# 🚀 Necesitas apuntar más alto.
#
#
# 🧗‍♂️ Piensa en algo más grande.
#
#
# 😢 Se acabaron los intentos. El número era 862.
#
#
# 💪 ¡Vaya número te ha puesto Mariloli! La próxima vez seguro lo consigues Paco.
#
#
# 🎯==============================🎯
#      ¡ADIVINA EL NÚMERO! 🎲
# 🎯==============================🎯
#
# 1️⃣  Modo Solitario
#    🤖 Ponte a prueba contra el ordenador. ¡Demuestra lo que vales!
#
# 2️⃣  Modo Multijugador
#    👥 Un jugador elige el número, el otro intenta adivinarlo.
#
# 3️⃣  Estadísticas
#    📊 Consulta tus logros y puntuaciones guardadas.
#
# 4️⃣  Salir
#    🚪 Cierra el juego.
#
#
# Cargando...
#
#
# 📊 ESTADÍSTICAS DE JUEGO 📊
# ----------------------------------------------------------------------
#         Modo    Nombre  Número a adivinar  Intentos        Fecha y hora
#    Solitario     Gorka                192        12 2025-11-08 19:48:39
#    Solitario Annabelle                617         5 2025-11-08 19:54:00
#    Solitario    Ulises                251         5 2025-11-08 19:56:03
#    Solitario      Anna                133         5 2025-11-08 20:00:54
# Multijugador     Laura                876         4 2025-11-08 20:02:33
#    Solitario Annabelle                326        12 2025-11-08 20:03:16
#    Solitario      Paco                234         8 2025-11-08 20:05:18
#    Solitario     María                138         5 2025-11-08 20:18:54
# Multijugador      Paco                862        20 2025-11-08 20:19:29
# ----------------------------------------------------------------------
#
# 🎯==============================🎯
#      ¡ADIVINA EL NÚMERO! 🎲
# 🎯==============================🎯
#
# 1️⃣  Modo Solitario
#    🤖 Ponte a prueba contra el ordenador. ¡Demuestra lo que vales!
#
# 2️⃣  Modo Multijugador
#    👥 Un jugador elige el número, el otro intenta adivinarlo.
#
# 3️⃣  Estadísticas
#    📊 Consulta tus logros y puntuaciones guardadas.
#
# 4️⃣  Salir
#    🚪 Cierra el juego.
#
# 👋 ¡Hasta luego!
#
# Saliendo...✨ Has salido del juego. ¡Vuelve pronto! 🎯

# %% [markdown]
# ## **Modo solitario**
# Modo  solitario  supone  que  el  número  a  adivinar  es  generado  aleatoriamente  por  el ordenador. El número a adivinar debe ser entre 1 y 1000.

# %%
guess.modo_solitario()

# %% [markdown]
# ## **Modo multijugador**
# Primero se escribe un número a adivinar y luego un segundo jugador
# intenta adivinarlo.

# %%
guess.modo_multijugador()

# %% [markdown]
# ## **Estadística**
# Se gane o se pierda se pide el nombre del jugador y se guarda esta información junto
# con el resultado de la partida en un fichero Excel.
# La opción estadística nos mostrara los datos almacenados en Excel.

# %%
guess.estadistica()
